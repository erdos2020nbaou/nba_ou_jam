# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from datetime import date
import requests

import nba_api
from nba_api.stats.static import teams
from nba_api.stats.endpoints import leaguegamefinder

# %% [markdown]
# ## Define season dates

# %%
#2015-2016 regular season start and end dates
start_15_16 = '2015-10-27'
end_15_16 = '2016-04-13'

#2016-2017 regular season start and end dates
start_16_17 = '2016-10-25'
end_16_17 = '2017-04-12'

#2016-2017 regular season start and end dates
start_17_18 = '2017-10-17'
end_17_18 = '2018-04-11'

#2018-2019 regular season start and end dates
start_18_19 = '2018-10-16'
end_18_19 = '2019-04-10'

# %% [markdown]
# ## Team Info

# %%
teams_df = pd.DataFrame(teams.get_teams())
teams_df.rename(columns={'id':'TEAM_ID'}, inplace=True)
teams_df.head()
# Out:
#   abbreviation         city             full_name     TEAM_ID   nickname  \
# 0          ATL      Atlanta         Atlanta Hawks  1610612737      Hawks
# 1          BOS       Boston        Boston Celtics  1610612738    Celtics
# 2          CLE    Cleveland   Cleveland Cavaliers  1610612739  Cavaliers
# 3          NOP  New Orleans  New Orleans Pelicans  1610612740   Pelicans
# 4          CHI      Chicago         Chicago Bulls  1610612741      Bulls
#
#            state  year_founded
# 0        Atlanta          1949
# 1  Massachusetts          1946
# 2           Ohio          1970
# 3      Louisiana          2002
# 4       Illinois          1966

# %% [markdown]
# ## Get all the games in the LeagueGameFinder

# %%
# Get **all** the games so we can filter to an individual GAME_ID
result = leaguegamefinder.LeagueGameFinder()
all_games = result.get_data_frames()[0]
all_games.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME     GAME_ID  \
# 0     22019  1612709926               MHU         Memphis Hustle  2021900026
# 1     22019  1612709911               IWA            Iowa Wolves  2021900026
# 2     22019  1612709920               RAP            Raptors 905  2021900566
# 3     22019  1612709911               IWA            Iowa Wolves  2021900567
# 4     22019  1612709929               CPS  College Park Skyhawks  2021900566
#
#     GAME_DATE      MATCHUP    WL  MIN  PTS     ...      FT_PCT  OREB  DREB  \
# 0  2020-03-15  MHU vs. IWA  None  120   56     ...       1.000     7    17
# 1  2020-03-15    IWA @ MHU  None  107   41     ...       0.833     2    15
# 2  2020-03-11  RAP vs. CPS     W  240  129     ...       0.731    14    43
# 3  2020-03-11    IWA @ RGV     W  240  128     ...       1.000     8    36
# 4  2020-03-11    CPS @ RAP     L  240  116     ...       0.538     8    29
#
#    REB  AST  STL  BLK  TOV  PF  PLUS_MINUS
# 0   24   13    5    1    4   7        15.6
# 1   17    8    1    7   11   8       -16.2
# 2   57   23    9   10   21  26        12.6
# 3   44   34   11    4   17  22         8.6
# 4   37   27   10    8   15  31       -12.2
#
# [5 rows x 28 columns]

# %%
#match NBA teams from 'teams_df' with 'all_games' to remove
#all non NBA-games from 'all_games' 
nba_games = pd.merge(teams_df, all_games, on = 'TEAM_ID', how = 'inner')

#remove columns in merged df coming from 'teams_df'
nba_games = nba_games.drop(list(teams_df.columns)[1:],1)

nba_games.head()
# Out:
#   abbreviation SEASON_ID TEAM_ABBREVIATION      TEAM_NAME     GAME_ID  \
# 0          ATL     22019               ATL  Atlanta Hawks  0021900969
# 1          ATL     22019               ATL  Atlanta Hawks  0021900957
# 2          ATL     22019               ATL  Atlanta Hawks  0021900943
# 3          ATL     22019               ATL  Atlanta Hawks  0021900930
# 4          ATL     22019               ATL  Atlanta Hawks  0021900905
#
#     GAME_DATE      MATCHUP WL  MIN  PTS     ...      FT_PCT  OREB  DREB  REB  \
# 0  2020-03-11  ATL vs. NYK  L  265  131     ...       0.808    15    38   53
# 1  2020-03-09  ATL vs. CHA  W  290  143     ...       0.593    12    41   53
# 2  2020-03-07    ATL @ MEM  L  240  101     ...       0.857    14    32   46
# 3  2020-03-06    ATL @ WAS  L  239  112     ...       0.667     6    30   36
# 4  2020-03-02  ATL vs. MEM  L  239   88     ...       0.938    16    27   43
#
#    AST  STL  BLK  TOV  PF  PLUS_MINUS
# 0   26    6    3   17  25         0.0
# 1   33    1    5   15  26         5.0
# 2   23    9    2   14  24       -17.0
# 3   25    9    4   17  25        -6.0
# 4   20    6    8   17  21       -39.0
#
# [5 rows x 28 columns]

# %%
#mask to filter dates within range
mask_15_16 = (nba_games['GAME_DATE'] >= start_15_16) & (nba_games['GAME_DATE'] <= end_15_16)
mask_16_17 = (nba_games['GAME_DATE'] >= start_16_17) & (nba_games['GAME_DATE'] <= end_16_17)
mask_17_18 = (nba_games['GAME_DATE'] >= start_17_18) & (nba_games['GAME_DATE'] <= end_17_18)
mask_18_19 = (nba_games['GAME_DATE'] >= start_18_19) & (nba_games['GAME_DATE'] <= end_18_19)

# %%
#regular season games held between given seasons
nba_games_15_16 = nba_games.loc[mask_15_16]
nba_games_16_17 = nba_games.loc[mask_16_17]
nba_games_17_18 = nba_games.loc[mask_17_18]
nba_games_18_19 = nba_games.loc[mask_18_19]

# %%
nba_games_15_16.head()
# Out:
#     abbreviation SEASON_ID TEAM_ABBREVIATION      TEAM_NAME     GAME_ID  \
# 377          ATL     22015               ATL  Atlanta Hawks  0021501221
# 378          ATL     22015               ATL  Atlanta Hawks  0021501203
# 379          ATL     22015               ATL  Atlanta Hawks  0021501188
# 380          ATL     22015               ATL  Atlanta Hawks  0021501173
# 381          ATL     22015               ATL  Atlanta Hawks  0021501157
#
#       GAME_DATE      MATCHUP WL  MIN  PTS     ...      FT_PCT  OREB  DREB  \
# 377  2016-04-13    ATL @ WAS  L  240   98     ...       0.742     9    38
# 378  2016-04-11    ATL @ CLE  L  240   94     ...       0.533    10    32
# 379  2016-04-09  ATL vs. BOS  W  240  118     ...       0.818     5    39
# 380  2016-04-07  ATL vs. TOR  W  239   95     ...       0.810     5    36
# 381  2016-04-05  ATL vs. PHX  W  242  103     ...       0.737    13    37
#
#      REB  AST  STL  BLK  TOV  PF  PLUS_MINUS
# 377   47   22   13    5   22  21       -11.0
# 378   42   23    8    6   15  18       -15.0
# 379   44   31   10   10   17  22        11.0
# 380   41   23    4   12   13  19         8.0
# 381   50   26   16    3   16  21        13.0
#
# [5 rows x 28 columns]

# %%
nba_games_15_16.keys()
# Out:
# Index(['abbreviation', 'SEASON_ID', 'TEAM_ABBREVIATION', 'TEAM_NAME',
#        'GAME_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'PTS', 'FGM', 'FGA',
#        'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB',
#        'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PLUS_MINUS'],
#       dtype='object')

# %%
#so we want to add a column to the df which contains the total points scored by both teams
unique_games = nba_games_15_16.groupby('GAME_ID').sum()

# %%
#lets start to build our features
# Out:
#                      MIN   PTS   FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT   FTM  \
# TEAM_ABBREVIATION
# ATL                19823  8433  3168  6923  37.607   815  2326   28.835  1282
# BKN                19767  8089  3136  6920  37.227   531  1508   28.572  1286
# BOS                19793  8669  3216  7318  36.091   717  2142   27.495  1520
# CHA                19871  8479  3036  6922  35.995   873  2410   29.647  1534
# CHI                19905  8335  3165  7170  36.344   651  1753   30.248  1354
# CLE                19859  8555  3171  6888  37.880   880  2428   29.721  1333
# DAL                19990  8388  3064  6900  36.473   806  2342   28.127  1454
# DEN                19844  8355  3093  7003  36.273   656  1943   27.620  1513
# DET                19879  8361  3111  7087  36.110   740  2148   28.191  1399
# GSW                19873  9421  3489  7159  40.055  1077  2592   33.967  1366
# HOU                19825  8737  3094  6847  37.105   878  2533   28.541  1671
# IND                19893  8377  3142  6985  36.960   663  1889   28.604  1430
# LAC                19832  8569  3141  6759  38.229   797  2190   29.944  1490
# LAL                19733  7982  2880  6956  34.056   639  2016   26.065  1583
# MEM                19846  8126  3019  6859  36.257   504  1521   26.870  1584
# MIA                19830  8204  3150  6697  38.696   498  1480   27.315  1406
# MIL                19844  8122  3145  6740  38.331   440  1277   28.279  1392
# MIN                19880  8398  3095  6668  38.124   455  1347   27.512  1753
